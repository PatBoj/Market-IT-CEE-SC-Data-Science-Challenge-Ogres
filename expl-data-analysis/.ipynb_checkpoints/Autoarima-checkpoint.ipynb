# %% [markdown]
# # Import Packages and Datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm # cross correlation
from prophet import Prophet
from datetime import datetime, timedelta

# Import the library
from pmdarima import auto_arima
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 10>()
#       7 from datetime import datetime, timedelta
#       9 # Import the library
# ---> 10 from pmdarima import auto_arima
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
currency_name = {
    'Pablos' : 'San Escobar Pablos',
    'Credits' : 'Galactic Credits',
    'Dragons' : '7 Kingdoms Golden Dragons'}

# %%
# Import data

data_currency = pd.read_csv('../data/currencies_history.csv')

data_currency.rename(columns = {
    'SanEscobarPablos' : 'Pablos', 
    'GalacticCredits' : 'Credits', 
    '7KingdomsGoldenDragons' : "Dragons"}, 
    inplace = True)
print(data_currency)

data_fuel_price = pd.read_csv('../data/Q4C_hint1.csv')
del data_fuel_price['Unnamed: 0']
data_fuel_price.rename(columns = {'bioFruitPulpPrice' : 'Pulp_price'}, inplace = True)
print(data_fuel_price)

data_ore = pd.read_csv('../data/Westeros_price.csv', sep = ';')
print(data_ore)
# Out:
#            Date    Pablos   Credits   Dragons
# 0    1000-01-03  1.000000  1.000000  1.000000
# 1    1000-01-10  0.992992  0.993418  0.988996
# 2    1000-01-17  0.988567  0.984193  0.981877
# 3    1000-01-24  0.999371  0.993381  0.984385
# 4    1000-01-31  1.014246  1.009505  0.992576
# ..          ...       ...       ...       ...
# 504  1009-09-01  3.734013  1.781049  1.152489
# 505  1009-09-08  3.725841  1.781063  1.151324
# 506  1009-09-15  3.667033  1.763477  1.145472
# 507  1009-09-22  3.694200  1.767235  1.145266
# 508  1009-09-29  3.734622  1.773911  1.148276
#
# [509 rows x 4 columns]
#            Date  Pulp_price
# 0    1000-01-03    1.000000
# 1    1000-01-10    1.038779
# 2    1000-01-17    1.027378
# 3    1000-01-24    0.993185
# 4    1000-01-31    0.979005
# ..          ...         ...
# 512  1009-10-27    0.765565
# 513  1009-11-03    0.777222
# 514  1009-11-10    0.791260
# 515  1009-11-17    0.797337
# 516  1009-11-24    0.808808
#
# [517 rows x 2 columns]
#            Date  WesterosOrePrice
# 0    1000-01-03          1.000000
# 1    1000-01-10          1.023292
# 2    1000-01-17          1.019991
# 3    1000-01-24          0.987717
# 4    1000-01-31          0.957423
# ..          ...               ...
# 512  1009-10-27          1.510558
# 513  1009-11-03          1.523103
# 514  1009-11-10          1.508391
# 515  1009-11-17          1.476787
# 516  1009-11-24          1.477897
#
# [517 rows x 2 columns]

# %% [markdown]
# # Creating Visuals

# %%
# Plot time series

plt.plot(data_currency.Date, data_currency.Pablos, label = currency_name['Pablos'])
plt.plot(data_currency.Date, data_currency.Credits, label = currency_name['Credits'])
plt.plot(data_currency.Date, data_currency.Dragons, label = currency_name['Dragons'])
plt.plot(data_fuel_price.Date, data_fuel_price.Pulp_price, '-.', label = 'Fruit Pulp Price')
plt.plot(data_ore.Date, data_ore.WesterosOrePrice, '-.', label = 'Ore Price')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Check and plot correlation between San Escobar currency price and fruit pulp price

plt.scatter(data_currency.Pablos, 
            data_fuel_price.Pulp_price[data_fuel_price.Date <= max(data_currency.Date)])
plt.show()

# Just a simple Pearson correlation
print(np.corrcoef(data_currency.Pablos,
                  data_fuel_price.Pulp_price[data_fuel_price.Date <= max(data_currency.Date)]))
# Out:
# [[ 1.        -0.6305692]
#  [-0.6305692  1.       ]]

# %%
# I was wondering if we can correlate this pulp price with other currencies, so I've checked

plt.scatter(data_currency.Credits, 
            data_fuel_price.Pulp_price[data_fuel_price.Date <= max(data_currency.Date)],
           label = currency_name['Credits'])
plt.scatter(data_currency.Dragons, 
            data_fuel_price.Pulp_price[data_fuel_price.Date <= max(data_currency.Date)],
           label = currency_name['Dragons'])
plt.legend()
plt.show()

# Just a simple Pearson correlation
print(np.corrcoef(data_currency.Credits,
                  data_fuel_price.Pulp_price[data_fuel_price.Date <= max(data_currency.Date)]))
print(np.corrcoef(data_currency.Dragons,
                  data_fuel_price.Pulp_price[data_fuel_price.Date <= max(data_currency.Date)]))
# Out:
# [[ 1.         -0.71368094]
#  [-0.71368094  1.        ]]
# [[ 1.         -0.82018292]
#  [-0.82018292  1.        ]]

# %%
# Compute and plot cross correlation between currencies and pulp price

cross_correlation_pablos = sm.tsa.stattools.ccf(data_currency.Pablos, 
                                                data_fuel_price.Pulp_price, adjusted = False)
cross_correlation_credits = sm.tsa.stattools.ccf(data_currency.Credits, 
                                                 data_fuel_price.Pulp_price, adjusted = False)
cross_correlation_dragons = sm.tsa.stattools.ccf(data_currency.Dragons, 
                                                 data_fuel_price.Pulp_price, adjusted = False)

plt.plot(np.arange(0, cross_correlation_pablos.size), 
         cross_correlation_pablos, 
         label = currency_name['Pablos'])
plt.plot(np.arange(0, cross_correlation_credits.size), 
         cross_correlation_credits, 
         label = currency_name['Credits'])
plt.plot(np.arange(0, cross_correlation_dragons.size),
         cross_correlation_dragons, 
         label = currency_name['Dragons'])
plt.xlabel('lag / week')
plt.ylabel('correlation')
plt.legend()
plt.show()

# %% [markdown]
# # Testing Prophet

# %%
def prophet_convertion(y, df = data_currency, ds = 'Date'):
    '''
    Transoforms data so profet package could work
    It picks two columns - date and predictor and
    changes their names to 'ds' and 'y'
    '''
    return pd.DataFrame().assign(ds = df[ds], y = df[y])

def simple_forecast(df):
    '''
    Makes simple forecast and plots it
    '''
    model = Prophet()
    model.fit(df)
    forecast = model.predict(future_currency)
    print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']])
    
    model.plot(forecast)
    plt.show()

# %%
# Temporary change year from 1000 to 2000 in to convert to datetime format
data_currency['Date'] = [date.replace("1", "2", 1) for date in data_currency['Date']]
data_currency['Date'] = pd.to_datetime(data_currency['Date'])

data_pablos = prophet_convertion('Pablos')
data_credits = prophet_convertion('Credits')
data_dragons = prophet_convertion('Dragons')

# %%
# Define list with forecasting dates

future_currency = list()
for i in range(1, 9):
	date = max(data_currency['Date']) + timedelta(days = 7 * i)
	future_currency.append([date])
    
future_currency = pd.DataFrame(future_currency)
future_currency.columns = ['ds']

# %%
simple_forecast(data_credits)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#           ds      yhat  yhat_lower  yhat_upper
# 0 2009-10-06  1.810682    1.762435    1.856557
# 1 2009-10-13  1.811797    1.764826    1.862565
# 2 2009-10-20  1.810994    1.766141    1.854897
# 3 2009-10-27  1.811510    1.761615    1.861265
# 4 2009-11-03  1.816075    1.769354    1.865514
# 5 2009-11-10  1.824266    1.776493    1.871118
# 6 2009-11-17  1.832988    1.787216    1.879146
# 7 2009-11-24  1.839479    1.790920    1.888788

# %%
simple_forecast(data_dragons)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#           ds      yhat  yhat_lower  yhat_upper
# 0 2009-10-06  1.149267    1.128754    1.168210
# 1 2009-10-13  1.148298    1.129011    1.167973
# 2 2009-10-20  1.145797    1.127841    1.164600
# 3 2009-10-27  1.144283    1.124873    1.164537
# 4 2009-11-03  1.145934    1.125428    1.166150
# 5 2009-11-10  1.150412    1.129752    1.171133
# 6 2009-11-17  1.155182    1.134610    1.174772
# 7 2009-11-24  1.158017    1.137157    1.178299

# %%
simple_forecast(data_pablos)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\PLBOJARSPA\Miniconda3\envs\my_env\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
#           ds      yhat  yhat_lower  yhat_upper
# 0 2009-10-06  3.538586    3.459272    3.628732
# 1 2009-10-13  3.538505    3.452024    3.628999
# 2 2009-10-20  3.540355    3.454785    3.619288
# 3 2009-10-27  3.549850    3.466786    3.630563
# 4 2009-11-03  3.566636    3.479997    3.649104
# 5 2009-11-10  3.585514    3.502346    3.668314
# 6 2009-11-17  3.602050    3.515188    3.686637
# 7 2009-11-24  3.616590    3.530144    3.704163

# %%
# I'm cutting history of San Escobar Pablos to get maybe get better results

simple_forecast(data_pablos[data_pablos['y'] >= 2])
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#           ds      yhat  yhat_lower  yhat_upper
# 0 2009-10-06  3.646385    3.488077    3.793053
# 1 2009-10-13  3.678067    3.530794    3.827590
# 2 2009-10-20  3.709748    3.550910    3.866866
# 3 2009-10-27  3.741430    3.582398    3.897026
# 4 2009-11-03  3.773111    3.621230    3.915324
# 5 2009-11-10  3.804793    3.637151    3.964421
# 6 2009-11-17  3.836474    3.681125    3.990586
# 7 2009-11-24  3.868156    3.718221    4.021158
